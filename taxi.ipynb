# %% [markdown]
# # 0. Imports

# %%
import gymnasium as gym
import numpy as np
import random
from tqdm import tqdm
import time

# %% [markdown]
# # 1. Setup an environment

# %%
env = gym.make("Taxi-v3", render_mode="ansi")

# %% [markdown]
# # 2. Q-Table Initialisation

# %%
# Collect all possible state and action spaces
state_space_size = env.observation_space.n
action_space_size = env.action_space.n

# Define a Q table that encompasses all possible state and action pairs
Q = np.zeros((state_space_size, action_space_size))

# %% [markdown]
# # 3. Hyperparameters

# %%
hyperparameters = {
    "alpha" : 0.1,
    "gamma" : 0.9,
    "epsilon": 1,
    "epsilon_decay" : 0.995,
    "epsilon_min" : 0.1,
    "episodes": 500,
    "stationary_penalty_factor" : 0.01
}

# %% [markdown]
# # 4. Training Loop

# %%
def train_taxi(env, 
               Q: np.array,
               episodes: int, 
               alpha: float, 
               gamma: float, 
               epsilon: float, 
               epsilon_decay: float, 
               epsilon_min: float,
               stationary_penalty_factor: float):
    
    """
    Function: Updates the Quality table for a agent over n episodes with provided hyper parameters
    Args:
        env: Gymnasium environment of the taxi agent,
        Q (np.array): The Q-table that maps & tracks the Quality of each state and action pair
        episodes (int): The number of episodes to simualte
        alpha (float): The learning rate
        gamma (float): The discount factor of future rewards
        epsilon (float): The exploration rate 
        epsilon_decay (float): Reduction factor of epsilon post an episode
        epsilon_min (float): The min epsilon that must be maintained
        stationary_penalty_factor (float): Penalty for being in teh same state for a long time
    """

    for episode in tqdm(range(episodes)):
        
        # Reset the environment for a new episode
        state, _ = env.reset()
        done = False
        trajectory = []
        while not done:

            # Trajectory update
            trajectory.append(state)

            # Choose the action based on exploration logic
            if random.uniform(0,1) < epsilon:
                action = env.action_space.sample()

            # Choose the action based on exploitation logic
            # Argmax of the given state
            else:
                action = np.argmax(Q[state])

            # Take the next step based on the action chosen
            next_state, reward, done, truncated, _ = env.step(action)
            done = done
            best_next_action_Q = np.argmax(Q[next_state])

            # Update the reward by a factor for being in the same state
            constant_state = 0
            for state in trajectory[::-1]:
                if state == next_state:
                    constant_state += 1

                else:
                    break

            constant_state_penalty = constant_state * stationary_penalty_factor
            reward = reward - constant_state_penalty

            # Update the Q state and action pair
            Q[state, action] = Q[state, action] + alpha * (reward + gamma * best_next_action_Q - Q[state, action])
            state = next_state

        epsilon = max(epsilon_min, epsilon_decay*epsilon)

    print("Training complete")

    return env, Q

# %%
env, Q = train_taxi(env=env,
                    Q=Q,
                    episodes=hyperparameters['episodes'],  
                    alpha=hyperparameters['alpha'],
                    gamma=hyperparameters['gamma'],
                    epsilon=hyperparameters['epsilon'],
                    epsilon_decay=hyperparameters['epsilon_decay'],
                    epsilon_min=hyperparameters['epsilon_min'],
                    stationary_penalty_factor=hyperparameters['stationary_penalty_factor'])
# Out:
#  36%|███▌      | 181/500 [1:18:29<2:18:19, 26.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 env, Q = train_taxi(env=env,
#       2                     Q=Q,
#       3                     episodes=hyperparameters['episodes'],
#       4                     alpha=hyperparameters['alpha'],
#       5                     gamma=hyperparameters['gamma'],
#       6                     epsilon=hyperparameters['epsilon'],
#       7                     epsilon_decay=hyperparameters['epsilon_decay'],
#       8                     epsilon_min=hyperparameters['epsilon_min'],
#       9                     stationary_penalty_factor=hyperparameters['stationary_penalty_factor'])
#
# Cell In[76], line 46, in train_taxi(env, Q, episodes, alpha, gamma, epsilon, epsilon_decay, epsilon_min, stationary_penalty_factor)
#      43     action = np.argmax(Q[state])
#      45 # Take the next step based on the action chosen
# ---> 46 next_state, reward, done, truncated, _ = env.step(action)
#      47 done = done
#      48 best_next_action_Q = np.argmax(Q[next_state])
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)    123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\envs\toy_text\taxi.py:395, in TaxiEnv.step(self, a)
#     393 def step(self, a):
#     394     transitions = self.P[self.s][a]
# --> 395     i = categorical_sample([t[0] for t in transitions], self.np_random)
#     396     p, s, r, t = transitions[i]
#     397     self.lastaction = a
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\gymnasium\envs\toy_text\utils.py:8, in categorical_sample(prob_n, np_random)
#       6 prob_n = np.asarray(prob_n)
#       7 csprob_n = np.cumsum(prob_n)
# ----> 8 return np.argmax(csprob_n > np_random.random())
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\numpy\_core\fromnumeric.py:1341, in argmax(a, axis, out, keepdims)
#    1252 """
#    1253 Returns the indices of the maximum values along an axis.
#    1254
#    (...)   1338 (2, 1, 4)
#    1339 """
#    1340 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1341 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\sharv\Documents\Sharvil\Projects\reinforcement-learning\rl-venv\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
state, _ = env.reset()
done = False

print("Taxi navigating...\n")
while not done:
    action = np.argmax(Q[state])
    state, reward, done, truncated, _ = env.step(action)
    print(env.render())  # ASCII animation of taxi world
    time.sleep(0.5)
# Out:
# Taxi navigating...
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 9
#       7 state, reward, done, truncated, _ = env.step(action)
#       8 print(env.render())  # ASCII animation of taxi world
# ----> 9 time.sleep(0.5)
#
# KeyboardInterrupt:
